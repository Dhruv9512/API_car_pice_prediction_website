# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Cleaned_Car_data.csv",index_col="Unnamed: 0")
df
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 812          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 814            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
#  Remove outliner from kms column
# def IQR(v):
#     Q1 = df[v].quantile(0.25)
#     Q3 = df[v].quantile(0.75)
#     IQR = Q3 - Q1
#     lower = Q1 - 1.5*IQR
#     upper = Q3 + 1.5*IQR
#     df[v]= np.where(df[v]<lower,lower,
#                         np.where(df[v]>upper,upper,df[v])
#                         )

# %%
# Data visualization of all columns
# for v in df.columns:
#     plt.figure(figsize=(12,6))
#     # if df[v].dtype == "int64":
#     sns.boxplot(data=df,x=df[v],color="red")

# %%
# outlier in "KMS - driven","year"
# IQR("kms_driven")
# IQR("year")

df
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 812          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 814            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
# Train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop("Price",axis=1),df["Price"],test_size=0.1,random_state=515)
df
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 812          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 814            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
# preproseccer

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ('cat',OneHotEncoder(handle_unknown='ignore'),["company","name","fuel_type"])
    ]
)

# model train
from sklearn.linear_model import LinearRegression

model = Pipeline(
    steps=[
        ('pre',preprocessor),
        ('model',LinearRegression())
    ]
)

model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['company', 'name',
#                                                    'fuel_type'])])),
#                 ('model', LinearRegression())])

# %%
# r2_score
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

y_pre = model.predict(x_test)
print("From r2_score:- ",r2_score(y_test,y_pre))
# Out:
# From r2_score:-  0.9308833528461615

# %%
ans=[]
for i in range(1000):
   
    from sklearn.model_selection import train_test_split
    x_train,x_test,y_train,y_test = train_test_split(df.drop("Price",axis=1),df["Price"],test_size=0.1,random_state=i)

    preprocessor = ColumnTransformer(
        transformers=[
            ('cat',OneHotEncoder(handle_unknown='ignore'),["company","name","fuel_type"])
        ]
    )

    # model train
    from sklearn.linear_model import LinearRegression

    model = Pipeline(
        steps=[
            ('pre',preprocessor),
            ('model',LinearRegression())
        ]
    )

    model.fit(x_train,y_train)
    y_pre = model.predict(x_test)
    scores = r2_score(y_test,y_pre)
    ans.append(scores)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop("Price",axis=1),df["Price"],test_size=0.1,random_state=np.argmax(ans))
# Out:
# np.int64(515)

# %%
import pickle as pkl
pkl.dump(model,open('model.pkl','wb'))
